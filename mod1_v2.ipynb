# %% [markdown]
# Este arquivo está vazio, apenas para um teste
#
# Fazer o upload em uma pasta no proprio computador, de preferencia um caminho de pastas igual o da aula e tentar refazer os comandos usando os passos do material.
